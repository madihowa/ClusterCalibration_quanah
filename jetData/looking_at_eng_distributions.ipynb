# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_jets = pd.read_csv("jets.csv")

# %%
plt.figure(figsize=(6, 4), dpi=150)
df_jets["cluster_ENG_CALIB_TOT"].plot(kind="hist",bins=100,histtype="step",label="cluster_ENG_CALIB_TOT")
df_jets["clusterE"].plot(kind="hist",bins=100,histtype="step",label="clusterE")
#df_jets[""]
plt.legend(fontsize=8)
#plt.yscale("log")
#plt.xscale("log")
plt.xlabel("cluster_ENG_CALIB_TOT", fontsize = 10)
#plt.savefig("cluster_ENG_CALIB_TOT.png")
plt.show()
